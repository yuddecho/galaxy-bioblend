# %%
import yaml
from transmolecule import TransMolecule

with open('config.yaml', 'r') as f:
    config = yaml.safe_load(f)

# 登录到 TransMolecule
trans_molecule = TransMolecule(config['transmolecule_url'], config['api_key'])
# Out:
# [History] now f3a63b25ef201245:12-4-tteat

# %%
# 打印用户所有历史记录信息
# trans_molecule.history.info()

# 选择指定历史记录
# trans_molecule.history.select('f1b9846ab84237e7')

# 打印当前历史所有记录数据
# trans_molecule.history.content()

# 创建历史记录
trans_molecule.history.create(name="12-4-tteatkkk")

# 上传当个文件
# trans_molecule.dataset.upload(file_path='data/test.json')

# 上传文件夹下所有文件
trans_molecule.dataset.upload(file_dir='data/pharma')

# 获取当前历史记录数据
data = trans_molecule.dataset.get()
print(data)

# 打印所有工具信息
# trans_molecule.tool.info()
# Out:
# [History] create 319886f37b7797fe:12-4-tteatkkk
# {'1uko_ligand.sdf': 'c5c981ee99940876', '1uko_rec.pdb': '2a36c19bf40c52a1'}

# %%
# 获取药效团提取工具，传入id或者name
pharma = trans_molecule.tool.get_tool(tool_id="pharma")

# 获取工具输入示例
pharma_input = pharma.inputs()
print(pharma_input)
# Out:
# {'pdb_file': {'id': None, 'src': 'hda'}, 'sdf_file': {'id': None, 'src': 'hda'}}

# %%
# 构建输入，将上传的文件数据的id放到对应value
pharma_input['pdb_file']['id'] = data['1uko_rec.pdb']
pharma_input['sdf_file']['id'] = data['1uko_ligand.sdf']
print(pharma_input)
# Out:
# {'pdb_file': {'id': '2a36c19bf40c52a1', 'src': 'hda'}, 'sdf_file': {'id': 'c5c981ee99940876', 'src': 'hda'}}

# %%
# 运行工具，提取药效团
job = pharma.run(pharma_input)
print(job)
# Out:
# {'outputs': [{'id': '15081ab54a789ee2', 'hda_ldda': 'hda', 'uuid': '80b333d1-4889-42fc-a545-25a6be140e55', 'hid': 3, 'file_ext': 'json', 'peek': None, 'model_class': 'HistoryDatasetAssociation', 'name': 'Pharma Res(json)', 'deleted': False, 'purged': False, 'visible': True, 'state': 'new', 'history_content_type': 'dataset', 'file_size': 0, 'create_time': '2025-12-04T09:14:05.961471', 'update_time': '2025-12-04T09:14:05.961474', 'data_type': 'galaxy.datatypes.text.Json', 'genome_build': '?', 'validated_state': 'unknown', 'validated_state_message': None, 'misc_info': None, 'misc_blurb': 'queued', 'tags': [], 'history_id': '319886f37b7797fe', 'metadata_dbkey': '?', 'metadata_data_lines': 0, 'output_name': 'output_json'}], 'output_collections': [], 'jobs': [{'model_class': 'Job', 'id': 'b0645819402ce636', 'state': 'new', 'exit_code': None, 'update_time': '2025-12-04T09:14:05.965877', 'create_time': '2025-12-04T09:14:05.958450', 'galaxy_version': '23.1', 'tool_id': 'pharma', 'history_id': '319886f37b7797fe'}], 'implicit_collections': [], 'produces_entry_points': False}

# %%
# 获取多肽设计工具
pharm_pep_gen = trans_molecule.tool.get_tool(tool_name="PharmaPepGen")

# 获取工具输入示例
pharm_pep_gen_in = pharm_pep_gen.inputs()
print(pharm_pep_gen_in)
# Out:
# {'input_files': [{'id': None, 'src': 'hda'}], 'num_samples': None}

# %%
# 构建参数，将上一步运行的结果作为输入
pharm_pep_gen_in['input_files'][0]['id'] = job['outputs'][0]['id']
pharm_pep_gen_in['num_samples'] = 10
print(pharm_pep_gen_in)
# Out:
# {'input_files': [{'id': '15081ab54a789ee2', 'src': 'hda'}], 'num_samples': 10}

# %%
# 运行工具
job2 = pharm_pep_gen.run(pharm_pep_gen_in)
print(job2)
# Out:
# {'outputs': [], 'output_collections': [{'hid': 4, 'history_id': '319886f37b7797fe', 'history_content_type': 'dataset_collection', 'visible': True, 'deleted': False, 'job_source_id': '26c6e36433226a2c', 'job_source_type': 'Job', 'job_state_summary': {'new': 1, 'resubmitted': 0, 'upload': 0, 'waiting': 0, 'queued': 0, 'running': 0, 'ok': 0, 'error': 0, 'failed': 0, 'paused': 0, 'deleting': 0, 'deleted': 0, 'stop': 0, 'stopped': 0, 'skipped': 0, 'all_jobs': 1}, 'create_time': '2025-12-04T09:14:35.192832', 'update_time': '2025-12-04T09:14:35.192836', 'id': '4e3a2bbe2997e144', 'name': 'PharmaPepGen Res(fasta)', 'collection_id': '4e3a2bbe2997e144', 'collection_type': 'list', 'populated': False, 'populated_state': 'new', 'populated_state_message': None, 'element_count': None, 'elements_datatypes': [], 'type': 'collection', 'model_class': 'HistoryDatasetCollectionAssociation', 'tags': [], 'url': 'history_content_typed?history_id=319886f37b7797fe&id=4e3a2bbe2997e144&type=dataset_collection', 'contents_url': 'contents_dataset_collection?hdca_id=4e3a2bbe2997e144&parent_id=4e3a2bbe2997e144', 'elements': [], 'output_name': 'output'}], 'jobs': [{'model_class': 'Job', 'id': '26c6e36433226a2c', 'state': 'new', 'exit_code': None, 'update_time': '2025-12-04T09:14:35.196463', 'create_time': '2025-12-04T09:14:35.192325', 'galaxy_version': '23.1', 'tool_id': 'pharma_pep_gen', 'history_id': '319886f37b7797fe'}], 'implicit_collections': [], 'produces_entry_points': False}

# %%
# 打印历史记录面板数据
trans_molecule.history.content()
# Out:
# id,	 hid,	 deleted,	 name,	 create_time
# c5c981ee99940876,	 1,	 False,	 1uko_ligand.sdf,	 2025-12-04T09:13:46.601822
# 2a36c19bf40c52a1,	 2,	 False,	 1uko_rec.pdb,	 2025-12-04T09:13:47.410000
# 15081ab54a789ee2,	 3,	 False,	 Pharma Res(json),	 2025-12-04T09:14:05.961471
# 4e3a2bbe2997e144,	 4,	 False,	 PharmaPepGen Res(fasta),	 2025-12-04T09:14:35.192832
# 6e0f198cc0c22322,	 5,	 False,	 PharmaRes(json)_sample_1,	 2025-12-04T09:14:40.317264
# a048e6f4c3b90e64,	 6,	 False,	 PharmaRes(json)_sample_10,	 2025-12-04T09:14:40.317268
# 38494c41afc4e63a,	 7,	 False,	 PharmaRes(json)_sample_2,	 2025-12-04T09:14:40.317271
# 680b17e947950440,	 8,	 False,	 PharmaRes(json)_sample_3,	 2025-12-04T09:14:40.317275
# 3238011cf6e619ce,	 9,	 False,	 PharmaRes(json)_sample_4,	 2025-12-04T09:14:40.317278
# d3018d65969b4a89,	 10,	 False,	 PharmaRes(json)_sample_5,	 2025-12-04T09:14:40.317281
# ddb80a62b83a4438,	 11,	 False,	 PharmaRes(json)_sample_6,	 2025-12-04T09:14:40.317284
# 183b606e8dac647b,	 12,	 False,	 PharmaRes(json)_sample_7,	 2025-12-04T09:14:40.317287
# 62b925a8aa386720,	 13,	 False,	 PharmaRes(json)_sample_8,	 2025-12-04T09:14:40.317291
# bb6cfb735c305b29,	 14,	 False,	 PharmaRes(json)_sample_9,	 2025-12-04T09:14:40.317294
